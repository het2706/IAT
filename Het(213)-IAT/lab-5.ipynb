# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'

# %%
df=pd.read_csv(url)

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
a=df.groupby('continent')['beer_servings']
b=a.mean()
count=b.max()
idd=b.idxmax()
id
print("Average Of Beer Is : ",id,count)
# Out:
# Average Of Beer Is :  EU 193.77777777777777

# %%
a=df.groupby('continent')['spirit_servings']
b=a.mean()
count=b.max()
idd=b.idxmax()
id
print("Average Of spirite Is : ",id,count)
# Out:
# Average Of spirite Is :  EU 132.55555555555554

# %%
a=df.groupby('continent')['wine_servings']
b=a.mean()
count=b.max()
idd=b.idxmax()
id
print("Average Of wine Is : ",id,count)
# Out:
# Average Of wine Is :  EU 142.22222222222223

# %%
a=df.groupby('continent')['wine_servings']
a.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %%
b=df.groupby('continent')['spirit_servings']
b.describe()
# Out:
#            count        mean        std   min    25%    50%     75%    max
# continent
# AF          53.0   16.339623  28.102794   0.0   1.00    3.0   19.00  152.0
# AS          44.0   60.840909  84.362160   0.0   1.00   16.0   98.00  326.0
# EU          45.0  132.555556  77.589115   0.0  81.00  122.0  173.00  373.0
# OC          16.0   58.437500  70.504817   0.0  18.00   37.0   65.25  254.0
# SA          12.0  114.750000  77.077440  25.0  65.75  108.5  148.75  302.0

# %%
c=df.groupby('continent')['beer_servings']
c.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %%
x=df.groupby('continent')['beer_servings']
y=x.mean()

new=y.sort_values(ascending=True)
new
# Out:
# continent
# AS     37.045455
# AF     61.471698
# OC     89.687500
# SA    175.083333
# EU    193.777778
# Name: beer_servings, dtype: float64

# %%
a=df.groupby('continent')
ans=a.median(numeric_only=True)
ans
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %%
a=df.groupby('continent')['spirit_servings']
b=a.mean()
print('avg Is : ',b)
c=a.min()
print('min is :',c)
d=a.max()
print('max is :',d)
# Out:
# avg Is :  continent
# AF     16.339623
# AS     60.840909
# EU    132.555556
# OC     58.437500
# SA    114.750000
# Name: spirit_servings, dtype: float64
# min is : continent
# AF     0
# AS     0
# EU     0
# OC     0
# SA    25
# Name: spirit_servings, dtype: int64
# max is : continent
# AF    152
# AS    326
# EU    373
# OC    254
# SA    302
# Name: spirit_servings, dtype: int64
